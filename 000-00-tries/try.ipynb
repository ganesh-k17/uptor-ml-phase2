# %%
from sklearn.datasets import fetch_california_housing

# %%
# 1.Load data directly from sklean datasets (California Housing dataset)
housing_bundle = fetch_california_housing(as_frame=True)

# Access the combined dataframe (Features + Target)
df = housing_bundle.frame

# %%
df_new = df.drop([0])
print(df_new.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
#
#    Longitude  MedHouseVal
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# 5    -122.25        2.697

# %%
df_new.iloc[[0]]
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#    Longitude  MedHouseVal
# 1    -122.22        3.585

# %%
df_new.loc[[1]]
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#    Longitude  MedHouseVal
# 1    -122.22        3.585

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
sns.displot([0, 1, 2, 3, 4, 5, 8,9])

plt.show()

# %%
sns.displot([0, 1, 2, 3, 4, 5, 8, 9], bins=10)

# %%
sns.displot([0, 1, 2, 3, 4,5, 5, 8, 9], bins=10)

# %%
# 1. You provide the exact X values (independent variable)
hours_studied = [1, 2, 3, 4, 5, 6, 7, 8]

# 2. You provide the exact Y values (dependent variable)
exam_scores = [50, 55, 65, 70, 75, 88, 92, 98]

# 3. Create the scatter plot by passing both X and Y
sns.scatterplot(x=hours_studied, y=exam_scores)
# Out:
# <Axes: >

# %%
# 1. Provide the exact X values (Time sequence)
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

# 2. Provide the exact Y values (The values you want to track)
stock_price = [150, 155, 152, 163, 160]

# 3. Create the line plot by passing both X and Y
sns.lineplot(x=days, y=stock_price)

# # 4. Add labels and a title
# plt.xlabel("Day of the Week")
# plt.ylabel("Stock Price ($)")
# plt.title("Weekly Stock Performance")

# # 5. Display the plot
# plt.show()
# Out:
# <Axes: >
