# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import fetch_california_housing

# %%
# 1.Load data directly from sklean datasets (California Housing dataset)
housing_bundle = fetch_california_housing(as_frame=True)
# Access the combined dataframe (Features + Target)
df = housing_bundle.frame

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# Do conversion for string columns to integer using LabelEncoder if needed

# obj  = LabelEncoder()
# for x in df.columns:
#     if df[x].dtype in ['object', 'str']:
#         df[x] = obj.fit_transform(df[x])

# %%
# 3. Split into train/test
x = df.drop(columns=['MedHouseVal'])
y = df['MedHouseVal']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
# display the values

print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (16512, 8)
# X_test shape: (4128, 8)
# y_train shape: (16512,)
# y_test shape: (4128,)

# %%
# display the actual data

print("X_train data:\n", x_train)
print("X_test data:\n", x_test)
print("y_train data:\n", y_train)
print("y_test data:\n", y_test)
# Out:
# X_train data:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 14196  3.2596      33.0  5.017657   1.006421      2300.0  3.691814     32.71
# 8267   3.8125      49.0  4.473545   1.041005      1314.0  1.738095     33.77
# 17445  4.1563       4.0  5.645833   0.985119       915.0  2.723214     34.66
# 14265  1.9425      36.0  4.002817   1.033803      1418.0  3.994366     32.69
# 2271   3.5542      43.0  6.268421   1.134211       874.0  2.300000     36.78
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 14196    -117.03
# 8267     -118.16
# 17445    -120.48
# 14265    -117.11
# 2271     -119.80
# ...          ...
# 11284    -117.96
# 11964    -117.43
# 5390     -118.38
# 860      -121.96
# 15795    -122.42
#
# [16512 rows x 8 columns]
# X_test data:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 15362  4.6050      16.0  7.002212   1.066372      1351.0  2.988938     33.36
# 16623  2.7266      28.0  6.131915   1.256738      1650.0  2.340426     35.36
# 18086  9.2298      25.0  7.237676   0.947183      1585.0  2.790493     37.31
# 2144   2.7850      36.0  5.289030   0.983122      1227.0  2.588608     36.77
# 3665   3.5521      17.0  3.988839   1.033482      1671.0  3.729911     34.22
#
#        Longitude
# 20046    -119.01
# 3024     -119.46
# 15663    -122.44
# 20484    -118.72
# 9814     -121.93
# ...          ...
# 15362    -117.22
# 16623    -120.83
# 18086    -122.05
# 2144     -119.76
# 3665     -118.37
#
# [4128 rows x 8 columns]
# y_train data:
#  14196    1.030
# 8267     3.821
# 17445    1.726
# 14265    0.934
# 2271     0.965
#          ...
# 11284    2.292
# 11964    0.978
# 5390     2.221
# 860      2.835
# 15795    3.250
# Name: MedHouseVal, Length: 16512, dtype: float64
# y_test data:
#  20046    0.47700
# 3024     0.45800
# 15663    5.00001
# 20484    2.18600
# 9814     2.78000
#           ...
# 15362    2.63300
# 16623    2.66800
# 18086    5.00001
# 2144     0.72300
# 3665     1.51500
# Name: MedHouseVal, Length: 4128, dtype: float64

# %%
# Scale features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Build model
clf = MLPRegressor(
    hidden_layer_sizes=(100,), 
    activation='relu',
    max_iter=500, 
    random_state=42, 
    verbose=True 
)

# %%
# Train model
clf.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 1.62056447
# Iteration 2, loss = 0.43678846
# Iteration 3, loss = 0.32700527
# Iteration 4, loss = 0.28069940
# Iteration 5, loss = 0.24814135
# Iteration 6, loss = 0.22803342
# Iteration 7, loss = 0.21538976
# Iteration 8, loss = 0.20787968
# Iteration 9, loss = 0.20154389
# Iteration 10, loss = 0.19743378
# Iteration 11, loss = 0.19321222
# Iteration 12, loss = 0.18961729
# Iteration 13, loss = 0.18678600
# Iteration 14, loss = 0.18383630
# Iteration 15, loss = 0.18157601
# Iteration 16, loss = 0.17968086
# Iteration 17, loss = 0.17775103
# Iteration 18, loss = 0.17538371
# Iteration 19, loss = 0.17423819
# Iteration 20, loss = 0.17407294
# Iteration 21, loss = 0.17085613
# Iteration 22, loss = 0.16995187
# Iteration 23, loss = 0.16823352
# Iteration 24, loss = 0.16798530
# Iteration 25, loss = 0.16717835
# Iteration 26, loss = 0.16566984
# Iteration 27, loss = 0.16730781
# Iteration 28, loss = 0.16499618
# Iteration 29, loss = 0.16261953
# Iteration 30, loss = 0.16145474
# Iteration 31, loss = 0.16053131
# Iteration 32, loss = 0.16002333
# Iteration 33, loss = 0.16125255
# Iteration 34, loss = 0.15863582
# Iteration 35, loss = 0.15835131
# Iteration 36, loss = 0.15795060
# Iteration 37, loss = 0.15703766
# Iteration 38, loss = 0.15707574
# Iteration 39, loss = 0.15768516
# Iteration 40, loss = 0.15525691
# Iteration 41, loss = 0.15632172
# Iteration 42, loss = 0.15467901
# Iteration 43, loss = 0.15438915
# Iteration 44, loss = 0.15556876
# Iteration 45, loss = 0.15329744
# Iteration 46, loss = 0.15273177
# Iteration 127, loss = 0.14078429
# Iteration 128, loss = 0.14104937
# Iteration 129, loss = 0.14622254
# Iteration 130, loss = 0.13979429
# Iteration 131, loss = 0.14207869
# Iteration 132, loss = 0.13959349
# Iteration 133, loss = 0.13931475
# Iteration 134, loss = 0.14040913
# Iteration 135, loss = 0.13881214
# Iteration 136, loss = 0.13959612
# Iteration 137, loss = 0.13932175
# Iteration 138, loss = 0.13920897
# Iteration 139, loss = 0.13851663
# Iteration 140, loss = 0.13819920
# Iteration 141, loss = 0.13957465
# Iteration 142, loss = 0.14007917
# Iteration 143, loss = 0.13807845
# Iteration 144, loss = 0.14255515
# Iteration 145, loss = 0.13939799
# Iteration 146, loss = 0.14331011
# Iteration 147, loss = 0.13863114
# Iteration 148, loss = 0.13804540
# Iteration 149, loss = 0.13968420
# Iteration 150, loss = 0.13820068
# Iteration 151, loss = 0.13809664
# Iteration 152, loss = 0.13752090
# Iteration 153, loss = 0.13804514
# Iteration 154, loss = 0.14141496
# Iteration 155, loss = 0.13744573
# Iteration 156, loss = 0.13758880
# Iteration 157, loss = 0.13741980
# Iteration 158, loss = 0.13708601
# Iteration 159, loss = 0.13719309
# Iteration 160, loss = 0.13852999
# Iteration 161, loss = 0.13748300
# Iteration 162, loss = 0.13840436
# Iteration 163, loss = 0.13816770
# Iteration 164, loss = 0.13695533
# Iteration 165, loss = 0.13705997
# Iteration 166, loss = 0.13731566
# Iteration 167, loss = 0.14251946
# Iteration 168, loss = 0.13778209
# Iteration 169, loss = 0.13699407
# Iteration 170, loss = 0.13671693
# Iteration 171, loss = 0.13831811
# Iteration 172, loss = 0.13850080
# Iteration 173, loss = 0.14784869
# Iteration 174, loss = 0.13677346
# Iteration 175, loss = 0.13598209
# Iteration 176, loss = 0.13693081
# Iteration 177, loss = 0.13709388
# Iteration 178, loss = 0.13696693
# Iteration 179, loss = 0.13825189
# Iteration 180, loss = 0.13573055
# Iteration 181, loss = 0.13524661
# Iteration 182, loss = 0.13526450
# Iteration 183, loss = 0.13522192
# Iteration 184, loss = 0.13523848
# Iteration 185, loss = 0.14037099
# Iteration 186, loss = 0.13569191
# Iteration 187, loss = 0.13577700
# Iteration 188, loss = 0.13517779
# Iteration 189, loss = 0.13919413
# Iteration 190, loss = 0.13562212
# Iteration 191, loss = 0.13543834
# Iteration 192, loss = 0.13609503
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(max_iter=500, random_state=42, verbose=True)

# %%
# Predict/evaluate
y_pred = clf.predict(x_test)
print("Predictions:", y_pred)
print("Actual:", y_test)
# Out:
# Predictions: [0.44550995 1.10798349 4.7554052  ... 4.86008377 0.73192556 1.7901959 ]
# Actual: 20046    0.47700
# 3024     0.45800
# 15663    5.00001
# 20484    2.18600
# 9814     2.78000
#           ...
# 15362    2.63300
# 16623    2.66800
# 18086    5.00001
# 2144     0.72300
# 3665     1.51500
# Name: MedHouseVal, Length: 4128, dtype: float64
